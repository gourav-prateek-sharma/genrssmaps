# %%
# !pip install sionna
# !git clone https://github.com/gourav-prateek-sharma/genrssmaps.git
# !pip install -e genrssmaps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.4/520.4 kB 10.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 75.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 74.3 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 26.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 96.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 81.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.7/271.7 kB 19.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.2
#     Uninstalling matplotlib-3.7.2:
#       Successfully uninstalled matplotlib-3.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python -m genrssmaps.gen_tx_pos --scene etoile --cell_size 4 --step_size 4 --out_dir . --master_csv
# Out:
# 2025-11-13 05:04:11.592762: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763010251.786171     128 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763010251.838876     128 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Scene 'etoile' bounds:
#   X: [-805.58, 669.88], Y: [-688.60, 517.04]
# Fine grid resolution: 4.0 m  →  nx=368, ny=301, total fine cells=110768
# Downsample factors: kx=1, ky=1  →  effective step=(4.0,4.0)
# Total number of phases: 1
# Phase  1/ 1: ox=0, oy=0  →  110768 points
# ...

# %%
# !python -m genrssmaps.gen_rss_csv --scene etoile --tx_positions_file ./master_etoile_cell4.0_step4.0.csv --out_dir ./etoile --format hdf5 --compression_level 8 --cell_size 4
# Out:
# 2025-11-11 06:04:07.091897: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762841047.114913     146 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762841047.121692     146 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# <frozen runpy>:128: RuntimeWarning: 'genrssmaps.gen_rss_csv' found in sys.modules after import of package 'genrssmaps', but prior to execution of 'genrssmaps.gen_rss_csv'; this may result in unpredictable behaviour
# Loaded 110768 tx positions from ./master_etoile_cell4.0_step4.0.csv
# ...

# %%
# %ls
# Out:
# genrssmaps/

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import HfApi
api = HfApi()

api.upload_folder(
    folder_path="./etoile",
    path_in_repo=".",
    repo_id="gourav-prateek-sharma/genrss-etoile-hdf5-cell2",
    repo_type="dataset",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_76/332786817.py in <cell line: 0>()
#       2 api = HfApi()
#       3
# ----> 4 api.upload_folder(
#       5     folder_path="./etoile",
#       6     path_in_repo=".",
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      87         kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#      88
# ---> 89         return fn(*args, **kwargs)
#      90
#      91     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    1611
#    1612         # Otherwise, call the function normally
# -> 1613         return fn(self, *args, **kwargs)
#    1614
#    1615     _inner.is_future_compatible = True  # type: ignore
#
# ...

# %%
# !pip install PyDrive2 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 41.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.6 MB/s eta 0:00:00

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

# Authenticate with your Google account
gauth = GoogleAuth()
gauth.LocalWebserverAuth()  # will open an auth link, copy-paste code
drive = GoogleDrive(gauth)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/oauth2client/clientsecrets.py in _loadfile(filename)
#     120     try:
# --> 121         with open(filename, 'r') as fp:
#     122             obj = json.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'client_secrets.json'
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pydrive2/auth.py in LoadClientConfigFile(self, client_config_file)
#     547         try:
# --> 548             client_type, client_info = clientsecrets.loadfile(
#     549                 client_config_file
#
# /usr/local/lib/python3.11/dist-packages/oauth2client/clientsecrets.py in loadfile(filename, cache)
#     164     if not cache:
# ...
